# %%
from ROOT import TH1D, TRandom1, TCanvas, TH1F, TMinuit
import ROOT as r

import numpy as np
import os
import sys
import re
import glob
#import pydot
import h5py
from scipy.optimize import *
import math
import pylab
from sklearn.metrics import roc_curve, roc_auc_score, auc
from skopt import *
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Welcome to JupyROOT 6.11/03

# %%
def setuphisto(qs, minnumber, check=0):
    '''
    This is a function to return a variable-bin histogram so that every bin has the same number of events.
    
    qs = a vector of doubles which you want to use to setup the binning.  I usually use the *background* events to setup the binning (since s/b is more sensitive to stat fluctuations when b is small than when s is small).
    minnumber = number of events in each bin.
    check: if 1, the output histogram is filled with qs and some debugging information is printed.

    The output is a vector of two 1D histograms with identical binning: one for signal and one for background.

    '''

    #out = r.Vector(out)

    qs = np.sort(qs)

    length = qs.size
    qs2 = np.empty((length))

    for i in xrange(0,length):
        qs2[i]=qs[i]


    #Now, determine the bin positions.
    binsnumber=(length-length%minnumber)/minnumber;
    
    #bins = np.empty(binsnumber+1)
    bins = np.array([])
    myindex = 0
    #print qs2[0]
    bins = np.concatenate((bins,[qs2[0]]))
    #bins = np.array(bins)
    #print bins.size
    for i in xrange(minnumber, length, minnumber):

        #std::cout << myindex << " a " << bins[myindex] << " " << qs2[i] << std::endl;

        if bins[myindex] == qs2[i]:
            myindex+=1
            
        else:
            bins = np.concatenate((bins,[qs2[i]]))
            myindex+=1
    
    
    bins = np.concatenate((bins, [qs2[length-1]]))
    #print bins[0]
    signal = TH1F("","",bins.size-1,bins)
    background = TH1F("","",bins.size-1,bins)

    #out.push_back(signal);
    #out.push_back(background);

    return signal, background

# %%
#Calculate AUC from likelihood 
def f_auc_sd(npar, deriv, f, exponents, flag):

        #loading files with tau values for signal and background
        fnsig="H2bb_sd.txt"
        fnbkg="g2bb_sd.txt"
        j=0
        fsig=pylab.loadtxt(fnsig)
        fbkg=pylab.loadtxt(fnbkg)
        
        #values of exponents set at function call from minimization routine
        a = exponents[0]
        b = exponents[1]
        c = exponents[2]
        d = exponents[3]
        e = exponents[4]
        
        if a==0 and b==0 and c==0 and d==0 and e==0:
            print a,b,c,d,e, 0.5
            return 0.5
        
        gs=0
        gb=0
        
        bkg_obs = np.zeros((100000))
        
        #loop over 100,000 sig and bkg events, measure product observable on them
        for j in xrange(0, 100000):
                T11H = fsig[j][0]  
                T12H = fsig[j][1]
                T13H = fsig[j][2]
                T22H = fsig[j][3] 
                T23H = fsig[j][4]
                
                T11g = fbkg[j][0]  
                T12g = fbkg[j][1]
                T13g = fbkg[j][2]
                T22g = fbkg[j][3] 
                T23g = fbkg[j][4]
                
                ts=(T11H**a)*(T12H**b)*(T13H**c)*(T22H**d)*(T23H**e)
                tb=(T11g**a)*(T12g**b)*(T13g**c)*(T22g**d)*(T23g**e)
                bkg_obs[j] = tb
                if(ts>gs):
                        gs=ts
                        
                if(tb>gb):
                        gb=tb
                        
        #find if the product observable measured on sig or bkg obtained a higher max val 
        
        max=0
        
        if(gs>gb):
                max=gs
        else:
                max=gb
                
        max = max+(1.0/10000.0)
        
        #set upper limit of range of histograms to max(=max+epsilon)
        
        #ridiculous number of bins
        #hs = TH1D("hs",("Convolved"), 1000, 0., max)
        #hb = TH1D("hb",("Convolved"), 1000, 0., max)
        hs, hb = setuphisto(bkg_obs, 2)
        hs.SetLineColor(2)
        hb.SetLineColor(9)
        
        #(inefficiently) loop over events again to fill histograms for product observable measured on sig and bkg
        for j in xrange(0, 100000):
                T11H = fsig[j][0]  
                T12H = fsig[j][1]
                T13H = fsig[j][2]
                T22H = fsig[j][3] 
                T23H = fsig[j][4]
                
                T11g = fbkg[j][0]  
                T12g = fbkg[j][1]
                T13g = fbkg[j][2]
                T22g = fbkg[j][3] 
                T23g = fbkg[j][4]
                
                ts=(T11H**a)*(T12H**b)*(T13H**c)*(T22H**d)*(T23H**e)
                tb=(T11g**a)*(T12g**b)*(T13g**c)*(T22g**d)*(T23g**e)
                hs.Fill(ts)
                hb.Fill(tb)
                
      
        lr = np.empty((1001,2))
        xb = 0
        xs = 0
        
        #calculate likelihood ratio
        for k in xrange(0, 1001):
                xb=hb.GetBinContent(k)
                xs=hs.GetBinContent(k)
                
                if(xs==0):
                        lr[k][0]=k
                        lr[k][1]=0.0
                        
                else:
                        lr[k][0]=k
                        lr[k][1]=(xb/(float)(xs+xb))
        
        #sort likelihood ratio in increasing order
        for p in xrange(0, 1001):
                for q in xrange(0, 1001-1):
                        if(lr[q][1]>lr[q+1][1]):
                                bint=lr[q+1][0]
                                lt=lr[q+1][1]
                                lr[q+1][0]=lr[q][0]
                                lr[q+1][1]=lr[q][1]
                                lr[q][0]=bint
                                lr[q][1]=lt
                                
        l = TH1D("l",("Likelihood"), 1001, 0., 1)
        ls = TH1D("ls",("ls"), 1001, 0., 1)
        lb = TH1D("lb",("lb"), 1001, 0., 1)      
        
        
        #get signal and background likelihoods
        for k in xrange(0, 1001):
                
                l.SetBinContent(k,lr[k][1])
                bin = (int)(lr[k][0])
                ls.SetBinContent(k, hs.GetBinContent(bin))
                lb.SetBinContent(k, hb.GetBinContent(bin))
                
        ls.Scale(1.0/ls.Integral())
        lb.Scale(1.0/lb.Integral())

        sums=0
        sumb=0
        
        x = np.empty((1001))
        y = np.empty((1001))
        
        cut=0
        
        #calculate fpr and tpr
        for k in xrange(0, 1001):
                sums+=ls.GetBinContent(k)
                sumb+=lb.GetBinContent(k)
                x[k]=sumb
                y[k]=sums
        
        #calculate AUC
        area = auc(x,y)
    
        print a,b,c,d,e,area
    
        hs.Delete()
        hb.Delete()
        ls.Delete()
        l.Delete()
        lb.Delete()
    
        #return for minimizaton routine
        return (1.0-area)

# %%
#f_auc_sd(coeff=[-1,0,0,-1,1])
npar=5
m=TMinuit(npar)
m.SetFCN(f_auc_sd)
#m.SetMaxIterations(250)
#Testing with init vals close to the ideal values identified from the histograms from MC to prevent Migrad from meandering aimlessly
par = [-2,0,0,-2,2]
#par = [0,0,0,0,0]
stepSize = np.empty((npar))
minVal = np.empty((npar))
maxVal = np.empty((npar))
parName = ['a','b','c','d','e']

for i in xrange(0,npar):
    stepSize[i] = 0.01
    minVal[i] = -5.1
    maxVal[i] = 5.1
#parName[0] = 65
#parName[1] = 66
#parName[2] = 67
#parName[3] = 68
#parName[4] = 69

for i in xrange(0,npar):
    m.DefineParameter(i, parName[i], par[i], stepSize[i], minVal[i], maxVal[i])
    
for i in xrange(0,11):
    print i
    m.Migrad()
    m.Migrad()
    m.Migrad()
# Out:
# 0
# -2.0 0.0 0.0 -2.0 2.0 0.703676855475
# -1.99989999943 0.0 0.0 -2.0 2.0 0.702718523507
# -2.00009999966 0.0 0.0 -2.0 2.0 0.707444832895
# -1.9989999534 0.0 0.0 -2.0 2.0 0.706811116813
# -2.00099995573 0.0 0.0 -2.0 2.0 0.699459923052
# -2.0 0.000100000064071 0.0 -2.0 2.0 0.706389622884
# -2.0 -0.000100000064072 0.0 -2.0 2.0 0.701469465649
# -2.0 0.00100000063437 0.0 -2.0 2.0 0.704273908024
# -2.0 -0.00100000063437 0.0 -2.0 2.0 0.704869703186
# -2.0 0.0 0.000100000064071 -2.0 2.0 0.707057935236
# -2.0 0.0 -0.000100000064072 -2.0 2.0 0.697711110398
# -2.0 0.0 0.00100000063437 -2.0 2.0 0.70060139165
# -2.0 0.0 -0.00100000063437 -2.0 2.0 0.707867290678
# -2.0 0.0 0.0 -1.99989999943 2.0 0.704053011353
# -2.0 0.0 0.0 -2.00009999966 2.0 0.707377172728
# -2.0 0.0 0.0 -1.9989999534 2.0 0.701096331452
# -2.0 0.0 0.0 -2.00099995573 2.0 0.710763971768
# -2.0 0.0 0.0 -2.0 2.00009999966 0.704735746809
# -2.0 0.0 0.0 -2.0 1.99989999943 0.700662796665
# -2.0 0.0 0.0 -2.0 2.00099995573 0.702647969983
# -2.0 0.0 0.0 -2.0 1.9989999534 0.701971648493
# -1.9989999534 0.0 0.0 -2.0 2.0 0.706811116813
# -1.99994999983 0.0 0.0 -2.0 2.0 0.700903399615
# -1.9999975 0.0 0.0 -2.0 2.0 0.703660754378
# -1.999999875 0.0 0.0 -2.0 2.0 0.703676855475
# -1.98999545247 0.0 0.0 -2.0 2.0 0.704522314845
# -2.00999546073 0.0 0.0 -2.0 2.0 0.704763512214
# -2.0 0.01 0.0 -2.0 2.0 0.707279219111
# -2.0 -0.01 0.0 -2.0 2.0 0.710405664
# -2.0 0.0 0.01 -2.0 2.0 0.706108608931
# -2.0 0.0 -0.01 -2.0 2.0 0.694726049722
# -2.0 0.0 0.0 -1.98999545247 2.0 0.71157266881
# -2.0 0.0 0.0 -2.00999546073 2.0 0.699498718524
# -2.0 0.0 0.0 -2.0 2.00999546073 0.706621541629
# -2.0 0.0 0.0 -2.0 1.98999545247 0.699866414659
# -1.98999545247 0.0 0.0 -2.0 2.0 0.704522314845
# -1.99949998806 0.0 0.0 -2.0 2.0 0.707477809133
# -1.99997499994 0.0 0.0 -2.0 2.0 0.704673904676
# -1.99999875 0.0 0.0 -2.0 2.0 0.703689877478
# -1.89955313236 0.0 0.0 -2.0 2.0 0.706849168339
# -2.09953822204 0.0 0.0 -2.0 2.0 0.708557431788
# -2.0 0.099993656397 0.0 -2.0 2.0 0.716860495437
# -2.0 -0.099993656397 0.0 -2.0 2.0 0.702533519199
# -2.0 0.0 0.099993656397 -2.0 2.0 0.707914626075
# -2.0 0.0 -0.099993656397 -2.0 2.0 0.710107205624
# -2.0 0.0 0.0 -1.89955313236 2.0 0.709114800882
# -2.0 0.0 0.0 -2.09953822204 2.0 0.711059272263
# -2.0 0.0 0.0 -2.0 2.09953822204 0.707176766358
# -2.0 0.0 0.0 -2.0 1.89955313236 0.706352233243
# -1.89955313236 0.0 0.0 -2.0 2.0 0.706849168339
# -1.99499885925 0.0 0.0 -2.0 2.0 0.703702053256
# -1.99974999687 0.0 0.0 -2.0 2.0 0.709795664443
# -1.99998749998 0.0 0.0 -2.0 2.0 0.704547341074
# -1.999999375 0.0 0.0 -2.0 2.0 0.703693726345
# -0.962291748998 0.0 0.0 -2.0 2.0 0.709513466084
# -2.94718377176 0.0 0.0 -2.0 2.0 0.713811481459
# -2.0 0.993605143296 0.0 -2.0 2.0 0.702502853067
# -2.0 -0.993605143296 0.0 -2.0 2.0 0.70732834293
# -2.0 0.0 0.993605143296 -2.0 2.0 0.691033230294
# -2.0 0.0 -0.993605143296 -2.0 2.0 0.699955637497
# -2.0 0.0 0.0 -0.962291748998 2.0 0.7013030071
# -2.0 0.0 0.0 -2.94718377176 2.0 0.711798788029
# -2.0 0.0 0.0 -2.0 2.94718377176 0.698669944421
# -2.0 0.0 0.0 -2.0 0.962291748998 0.440883061889
# -0.962291748998 0.0 0.0 -2.0 2.0 0.709513466084
# -1.94988730411 0.0 0.0 -2.0 2.0 0.705334085633
# -1.99749971323 0.0 0.0 -2.0 2.0 0.704163587967
# -1.99987499914 0.0 0.0 -2.0 2.0 0.70461121801
# -1.99999374999 0.0 0.0 -2.0 2.0 0.703570883315
# -1.9999996875 0.0 0.0 -2.0 2.0 0.703676855475
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -1.88210020851 0.0 0.0 -2.0 2.0 0.709794456677
# -1.99413408697 0.0 0.0 -2.0 2.0 0.706134392044
# -1.99970677849 0.0 0.0 -2.0 2.0 0.709733517188
# -1.99998533911 0.0 0.0 -2.0 2.0 0.704489479761
# -1.99999926696 0.0 0.0 -2.0 2.0 0.703693726345
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -1.88210020851 0.0 0.0 -2.0 2.0 0.709794456677
# -1.99413408697 0.0 0.0 -2.0 2.0 0.706134392044
# -1.99970677849 0.0 0.0 -2.0 2.0 0.709733517188
# -1.99998533911 0.0 0.0 -2.0 2.0 0.704489479761
# -1.99999926696 0.0 0.0 -2.0 2.0 0.703693726345
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -1.88210020851 0.0 0.0 -2.0 2.0 0.709794456677
# -1.99413408697 0.0 0.0 -2.0 2.0 0.706134392044
# -1.99970677849 0.0 0.0 -2.0 2.0 0.709733517188
# -1.99998533911 0.0 0.0 -2.0 2.0 0.704489479761
# -1.99999926696 0.0 0.0 -2.0 2.0 0.703693726345
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -1.88210020851 0.0 0.0 -2.0 2.0 0.709794456677
# -1.99413408697 0.0 0.0 -2.0 2.0 0.706134392044
# -1.99970677849 0.0 0.0 -2.0 2.0 0.709733517188
# -1.99998533911 0.0 0.0 -2.0 2.0 0.704489479761
# -1.99999926696 0.0 0.0 -2.0 2.0 0.703693726345
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -1.88210020851 0.0 0.0 -2.0 2.0 0.709794456677
# -1.99413408697 0.0 0.0 -2.0 2.0 0.706134392044
# -1.99970677849 0.0 0.0 -2.0 2.0 0.709733517188
# -1.99998533911 0.0 0.0 -2.0 2.0 0.704489479761
# -1.99999926696 0.0 0.0 -2.0 2.0 0.703693726345
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# -2.0 0.0 0.0 -2.0 2.0 0.703676855475
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# -1.52164168907 0.0 0.0 -2.0 2.0 0.712695226602
# -2.45837497204 0.0 0.0 -2.0 2.0 0.706041108272
# -1.90577663567 0.0 0.0 -2.0 2.0 0.715750759584
# -2.093423391 0.0 0.0 -2.0 2.0 0.706615284232
# -2.0 0.509150424899 0.0 -2.0 2.0 0.706089156542
# -2.0 -0.509150424899 0.0 -2.0 2.0 0.704784533794
# -2.0 0.101993200136 0.0 -2.0 2.0 0.709394516971
# -2.0 -0.101993200136 0.0 -2.0 2.0 0.698559300558
# -2.0 0.0 0.509150424899 -2.0 2.0 0.710463996259
# -2.0 0.0 -0.509150424899 -2.0 2.0 0.699092770314
# -2.0 0.0 0.101993200136 -2.0 2.0 0.715321799881
# -2.0 0.0 -0.101993200136 -2.0 2.0 0.70566643681
# -2.0 0.0 0.0 -1.52164168907 2.0 0.705070200952
# -2.0 0.0 0.0 -2.45837497204 2.0 0.713095549823
# -2.0 0.0 0.0 -1.90577663567 2.0 0.7107748686
# -2.0 0.0 0.0 -2.093423391 2.0 0.706868206175
# -2.0 0.0 0.0 -2.0 2.45837497204 0.706888692819
# -2.0 0.0 0.0 -2.0 1.52164168907 0.721289148445
# -2.0 0.0 0.0 -2.0 2.093423391 0.709802507837
# -2.0 0.0 0.0 -2.0 1.90577663567 0.717395850439
# 0.494050989429 2.44507024688 0.0 -2.0 2.0 0.641370699022
# 0.494050989429 0.0 2.44507024688 -2.0 2.0 0.654485886722
# -2.0 2.44507024688 2.44507024688 -2.0 2.0 0.628130504404
# 0.494050989429 0.0 0.0 0.494050989429 2.0 0.68980372351
# -2.0 2.44507024688 0.0 0.494050989429 2.0 0.681049297358
# -2.0 0.0 2.44507024688 0.494050989429 2.0 0.680927396914
# 0.494050989429 0.0 0.0 -2.0 4.00438123699 0.681167591267
# -2.0 2.44507024688 0.0 -2.0 4.00438123699 0.685360953518
# -2.0 0.0 2.44507024688 -2.0 4.00438123699 0.679831374322
# -2.0 0.0 0.0 0.494050989429 4.00438123699 0.695079842033
# -1.02807963737 0.0 0.0 -2.0 2.0 0.710915206752
# -2.89218667399 0.0 0.0 -2.0 2.0 0.701085830059
# -2.0 1.01321358705 0.0 -2.0 2.0 0.701596264368
# -2.0 -1.01321358705 0.0 -2.0 2.0 0.703509084512
# -2.0 0.0 1.01321358705 -2.0 2.0 0.695343913803
# -2.0 0.0 -1.01321358705 -2.0 2.0 0.699381384486
# -2.0 0.0 0.0 -1.02807963737 2.0 0.699433083437
# -2.0 0.0 0.0 -2.89218667399 2.0 0.710937208941
# -2.0 0.0 0.0 -2.0 2.89218667399 0.706725047815
# -2.0 0.0 0.0 -2.0 1.02807963737 0.497452549218
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 1
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 2
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 3
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 4
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 5
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 6
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 7
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 8
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 9
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 10
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
# 0.494050989429 0.0 0.0 -2.0 2.0 0.699314615945
# -4.00438123699 0.0 0.0 -2.0 2.0 0.70117425302
# -2.0 2.44507024688 0.0 -2.0 2.0 0.680115832507
# -2.0 -2.44507024688 0.0 -2.0 2.0 0.6938919029
# -2.0 0.0 2.44507024688 -2.0 2.0 0.660776663147
# -2.0 0.0 -2.44507024688 -2.0 2.0 0.646098317387
# -2.0 0.0 0.0 0.494050989429 2.0 0.701812068134
# -2.0 0.0 0.0 -4.00438123699 2.0 0.510317950025
# -2.0 0.0 0.0 -2.0 4.00438123699 0.692074627436
# -2.0 0.0 0.0 -2.0 -0.494050989429 0.212572144289
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 a           -2.00000e+00  1.00000e-02   -5.10000e+00  5.10000e+00
#      2 b            0.00000e+00  1.00000e-02   -5.10000e+00  5.10000e+00
#      3 c            0.00000e+00  1.00000e-02   -5.10000e+00  5.10000e+00
#      4 d           -2.00000e+00  1.00000e-02   -5.10000e+00  5.10000e+00
#      5 e            2.00000e+00  1.00000e-02   -5.10000e+00  5.10000e+00
#  **********
#  **    1 **MIGRAD
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=1.01856e-312 FROM MIGRAD    STATUS=INITIATE      159 CALLS         160 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00   1.00000e-02   0.00000e+00 -1.97626e-323
#    2  b            0.00000e+00   1.00000e-02   0.00000e+00 -1.97626e-323
#    3  c            0.00000e+00   1.00000e-02   0.00000e+00 -1.97626e-323
#    4  d           -2.00000e+00   1.00000e-02   0.00000e+00 -1.97626e-323
#    5  e            2.00000e+00   1.00000e-02   0.00000e+00 -1.97626e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED     200 CALLS         201 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01  1.73831e-308
#    2  b            0.00000e+00           nan   5.00000e-01  1.73831e-308
#    3  c            0.00000e+00           nan   5.00000e-01  1.73831e-308
#    4  d           -2.00000e+00           nan   5.00000e-01  1.73831e-308
#    5  e            2.00000e+00           nan   5.00000e-01  1.73831e-308
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan
#  **********
#  **    2 **MIGRAD
#  **********
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=0 FROM MIGRAD    STATUS=INITIATE       10 CALLS         211 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -4.94066e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -4.94066e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -4.94066e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -4.94066e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -4.94066e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED      10 CALLS         211 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -4.94066e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -4.94066e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -4.94066e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -4.94066e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -4.94066e-323
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan
#  **********
#  **    3 **MIGRAD
#  **********
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=0 FROM MIGRAD    STATUS=INITIATE       10 CALLS         221 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED      10 CALLS         221 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan
#  **********
#  **    4 **MIGRAD
#  **********
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=0 FROM MIGRAD    STATUS=INITIATE       10 CALLS         231 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED      10 CALLS         231 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan
#  **********
#  **    5 **MIGRAD
#  **********
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=0 FROM MIGRAD    STATUS=INITIATE       10 CALLS         241 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED      10 CALLS         241 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan
#  **********
#  **    6 **MIGRAD
#  **********
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=0 FROM MIGRAD    STATUS=INITIATE       10 CALLS         251 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED      10 CALLS         251 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan
#  **********
#  **    7 **MIGRAD
#  **********
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=0 FROM MIGRAD    STATUS=INITIATE       10 CALLS         261 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED      10 CALLS         261 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan
#  **********
#  **    8 **MIGRAD
#  **********
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=0 FROM MIGRAD    STATUS=INITIATE       10 CALLS         271 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED      10 CALLS         271 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan
#  **********
#  **    9 **MIGRAD
#  **********
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=0 FROM MIGRAD    STATUS=INITIATE       10 CALLS         281 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED      10 CALLS         281 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan
#  **********
#  **   10 **MIGRAD
#  **********
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=0 FROM MIGRAD    STATUS=INITIATE       10 CALLS         291 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED      10 CALLS         291 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan
#  **********
#  **   11 **MIGRAD
#  **********
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=0 FROM MIGRAD    STATUS=INITIATE       10 CALLS         301 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED      10 CALLS         301 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
# ...
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan
#  **********
#  **   27 **MIGRAD
#  **********
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=0 FROM MIGRAD    STATUS=INITIATE       10 CALLS         461 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED      10 CALLS         461 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan
#  **********
#  **   28 **MIGRAD
#  **********
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=0 FROM MIGRAD    STATUS=INITIATE       10 CALLS         471 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED      10 CALLS         471 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan
#  **********
#  **   29 **MIGRAD
#  **********
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=0 FROM MIGRAD    STATUS=INITIATE       10 CALLS         481 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED      10 CALLS         481 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan
#  **********
#  **   30 **MIGRAD
#  **********
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=0 FROM MIGRAD    STATUS=INITIATE       10 CALLS         491 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED      10 CALLS         491 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan
#  **********
#  **   31 **MIGRAD
#  **********
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=0 FROM MIGRAD    STATUS=INITIATE       10 CALLS         501 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED      10 CALLS         501 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan
#  **********
#  **   32 **MIGRAD
#  **********
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=0 FROM MIGRAD    STATUS=INITIATE       10 CALLS         511 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED      10 CALLS         511 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan
#  **********
#  **   33 **MIGRAD
#  **********
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-04
#  FCN=0 FROM MIGRAD    STATUS=INITIATE       10 CALLS         521 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=0 FROM MIGRAD    STATUS=CONVERGED      10 CALLS         521 TOTAL
#                      EDM=-nan    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  a           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    2  b            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    3  c            0.00000e+00           nan   5.00000e-01 -1.97626e-323
#    4  d           -2.00000e+00           nan   5.00000e-01 -1.97626e-323
#    5  e            2.00000e+00           nan   5.00000e-01 -1.97626e-323
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  5    ERR DEF=1
#         inf  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00        inf  0.000e+00  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00        inf  0.000e+00  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00        inf  0.000e+00
#   0.000e+00  0.000e+00  0.000e+00  0.000e+00        inf
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5
#         1     -nan    -nan  0.000  0.000  0.000  0.000
#         2      nan   0.000   -nan  0.000  0.000  0.000
#         3      nan   0.000  0.000   -nan  0.000  0.000
#         4      nan   0.000  0.000  0.000   -nan  0.000
#         5     -nan   0.000  0.000  0.000  0.000   -nan

# %%
print m.fCstatu

outpar = np.empty((npar))
err = np.empty((npar))
eppar = np.empty((npar))
empar = np.empty((npar))
epar = np.empty((npar))

for i in xrange(0,npar):
    m.GetParameter(i,r.Double(outpar[i]),r.Double(err[i]));
    m.mnerrs(i,r.Double(eppar[i]),r.Double(empar[i]),r.Double(epar[i]),r.Double(par[i]));
        
print "THE ANSWER IS "
print "a,b,c,d,e:", outpar

# %%
#Calculate AUC from likelihood 
#def f_auc_sd(npar, deriv, f, exponents, flag):

#loading files with tau values for signal and background
fnsig="H2bb_sd.txt"
fnbkg="g2bb_sd.txt"
j=0
fsig=pylab.loadtxt(fnsig)
fbkg=pylab.loadtxt(fnbkg)
        
#values of exponents set at function call from minimization routine

exponents = [-2,0,0,-2,2]

a = exponents[0]
b = exponents[1]
c = exponents[2]
d = exponents[3]
e = exponents[4]
        
if a==0 and b==0 and c==0 and d==0 and e==0:
    print a,b,c,d,e, 0.5
    #return 0.5
        
gs=0
gb=0
        
bkg_obs = np.zeros((100000))
        
#loop over 100,000 sig and bkg events, measure product observable on them
for j in xrange(0, 100000):
    T11H = fsig[j][0]  
    T12H = fsig[j][1]
    T13H = fsig[j][2]
    T22H = fsig[j][3] 
    T23H = fsig[j][4]
            
    T11g = fbkg[j][0]  
    T12g = fbkg[j][1]
    T13g = fbkg[j][2]
    T22g = fbkg[j][3] 
    T23g = fbkg[j][4]
                
    ts=(T11H**a)*(T12H**b)*(T13H**c)*(T22H**d)*(T23H**e)
    tb=(T11g**a)*(T12g**b)*(T13g**c)*(T22g**d)*(T23g**e)
    bkg_obs[j] = tb
    if(ts>gs):
        gs=ts
                    
    if(tb>gb):
        gb=tb
                    
#find if the product observable measured on sig or bkg obtained a higher max val 
        
max=0
        
if(gs>gb):
    max=gs
else:
    max=gb
            
max = max+(1.0/10000.0)
        
#set upper limit of range of histograms to max(=max+epsilon)

#ridiculous number of bins
#hs = TH1D("hs",("Convolved"), 1000, 0., max)
#hb = TH1D("hb",("Convolved"), 1000, 0., max)
hs, hb = setuphisto(bkg_obs, 2)
hs.SetLineColor(2)
hb.SetLineColor(9)
        
#(inefficiently) loop over events again to fill histograms for product observable measured on sig and bkg
for j in xrange(0, 100000):
    T11H = fsig[j][0]  
    T12H = fsig[j][1]
    T13H = fsig[j][2]
    T22H = fsig[j][3] 
    T23H = fsig[j][4]
            
    T11g = fbkg[j][0]  
    T12g = fbkg[j][1]
    T13g = fbkg[j][2]
    T22g = fbkg[j][3] 
    T23g = fbkg[j][4]
                
    ts=(T11H**a)*(T12H**b)*(T13H**c)*(T22H**d)*(T23H**e)
    tb=(T11g**a)*(T12g**b)*(T13g**c)*(T22g**d)*(T23g**e)
    hs.Fill(ts)
    hb.Fill(tb)
                

lr = np.empty((1001,2))
xb = 0
xs = 0
        
#calculate likelihood ratio
for k in xrange(0, 1001):
    xb=hb.GetBinContent(k)
    xs=hs.GetBinContent(k)
            
    if(xs==0):
        lr[k][0]=k
        lr[k][1]=0.0
                    
    else:
        lr[k][0]=k
        lr[k][1]=(xb/(float)(xs+xb))
                    
#sort likelihood ratio in increasing order
for p in xrange(0, 1001):
    for q in xrange(0, 1001-1):
        if(lr[q][1]>lr[q+1][1]):
            bint=lr[q+1][0]
            lt=lr[q+1][1]
            lr[q+1][0]=lr[q][0]
            lr[q+1][1]=lr[q][1]
            lr[q][0]=bint
            lr[q][1]=lt
                            
l = TH1D("l",("Likelihood"), 1001, 0., 1)
ls = TH1D("ls",("ls"), 1001, 0., 1)
lb = TH1D("lb",("lb"), 1001, 0., 1)      
        
        
#get signal and background likelihoods
for k in xrange(0, 1001):
    
    l.SetBinContent(k,lr[k][1])
    bin = (int)(lr[k][0])
    ls.SetBinContent(k, hs.GetBinContent(bin))
    lb.SetBinContent(k, hb.GetBinContent(bin))
                
ls.Scale(1.0/ls.Integral())
lb.Scale(1.0/lb.Integral())

sums=0
sumb=0
        
x = np.empty((1001))
y = np.empty((1001))
        
cut=0
        
#calculate fpr and tpr
for k in xrange(0, 1001):
    sums+=ls.GetBinContent(k)
    sumb+=lb.GetBinContent(k)
    x[k]=sumb
    y[k]=sums
            
        #calculate AUC
area = auc(x,y)
        
print a,b,c,d,e,area
        
hs.Draw()
hb.Draw("same")
        
        #hs.Delete()
        #hb.Delete()
        #ls.Delete()
        #l.Delete()
        #lb.Delete()
    
        #return for minimizaton routine
        #return (1.0-area)
# Out:
# -2 0 0 -2 2 0.703676855475
# Warning in <TROOT::Append>: Replacing existing TH1: l (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: ls (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: lb (Potential memory leak).
